# %%
import caffe
import os.path
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline
import numpy as np
gei_root = '/home/wutong/caffe/gei/'

# %%
caffe.set_mode_gpu()
# We create a solver that fine-tunes from a previously trained network.
solver = caffe.SGDSolver(gei_root + 'gei_caffenet/solver.prototxt')

# %%
# each output is (batch size, feature dim, spatial dim)
[(k, v.data.shape) for k, v in solver.net.blobs.items()]
# Out:
# [('data', (32, 1, 128, 128)),
#  ('label', (32,)),
#  ('label_mnist_1_split_0', (32,)),
#  ('label_mnist_1_split_1', (32,)),
#  ('conv1', (32, 20, 124, 124)),
#  ('pool1', (32, 20, 62, 62)),
#  ('conv2', (32, 50, 58, 58)),
#  ('pool2', (32, 50, 29, 29)),
#  ('ip1', (32, 500)),
#  ('ip2', (32, 123)),
#  ('ip2_ip2_0_split_0', (32, 123)),
#  ('ip2_ip2_0_split_1', (32, 123)),
#  ('accuracy', ()),
#  ('loss', ())]

# %%
# just print the weight sizes (not biases)
[(k, v[0].data.shape) for k, v in solver.net.params.items()]
# Out:
# [('conv1', (20, 3, 11, 11)),
#  ('conv2', (50, 10, 5, 5)),
#  ('fc3', (500, 2450)),
#  ('fc4ft', (123, 500))]

# %%
solver.net.forward()  # train net
solver.test_nets[0].forward()  # test net (there can be more than one)
# Out:
# {'accuracy': array(0.0, dtype=float32),
#  'loss': array(4.785849571228027, dtype=float32)}

# %%
imshow(solver.net.blobs['data'].data[:8, 0].transpose(1, 0, 2).reshape(128, 8*128), cmap='gray')
print solver.net.blobs['label'].data[:8]
# Out:
# [ 0.  0.  0.  0.  0.  0.  0.  0.]

# %%
imshow(solver.test_nets[0].blobs['data'].data[:8, 0].transpose(1, 0, 2).reshape(128, 8*128), cmap='gray')
print solver.test_nets[0].blobs['label'].data[:8]
# Out:
# [ 0.  0.  1.  1.  2.  2.  3.  3.]

# %%
solver.step(1)

# %%
# %%time
niter = 100000
test_interval = 100
# losses will also be stored in the log
train_loss = zeros(niter)
test_loss = zeros(niter)
test_acc = zeros(int(np.ceil(niter / test_interval)))
#output = zeros((niter, 8, 10))

# the main solver loop
for it in range(niter):
    solver.step(1)  # SGD by Caffe
    
    # store the train loss
    train_loss[it] = solver.net.blobs['loss'].data
    
    # store the output on the first test batch
    # (start the forward pass at conv1 to avoid loading new data)
    solver.test_nets[0].forward(start='conv1')
    
    #output[it] = solver.test_nets[0].blobs['ip2'].data[:8]
    
    # run a full test every so often
    # (Caffe can also do this for us and write to a log, but we show here
    #  how to do it directly in Python, where more complicated things are easier.)
    if it % test_interval == 0:
        print 'Iteration', it, 'testing...'
# Iteration 1780 testing...
# Iteration 1800 testing...
# Iteration 1820 testing...
# Iteration 1840 testing...
# Iteration 1860 testing...
# Iteration 1880 testing...
# Iteration 1900 testing...
# Iteration 1920 testing...
# Iteration 1940 testing...
# Iteration 1960 testing...
# Iteration 1980 testing...
# CPU times: user 52min 7s, sys: 14min 58s, total: 1h 7min 6s
# Wall time: 53min 3s

# %%
_, ax1 = subplots()
ax2 = ax1.twinx()
ax1.plot(arange(niter), train_loss,label="train loss")
ax2.plot(test_interval * arange(len(test_acc)), test_acc,"r",label="test accuracy")
ax1.set_xlabel('iteration')
ax1.set_ylabel('train loss')
ax2.set_ylabel('test accuracy')
ax1.legend(loc="lower right")
ax2.legend(loc="lower left")

# %%
test_acc.max()
# Out:
# 0.93489999999999995

# %%
_, ax3 = subplots()
ax4 = ax3.twinx()
ax3.plot(arange(niter), train_loss,label="train loss")
ax4.plot(arange(niter),test_loss,"r",label="test loss")
ax3.set_xlabel('iteration')
ax3.set_ylabel('train loss')
ax4.set_ylabel('test loss')
ax3.legend(loc="best")
ax4.legend(loc="best")

# %%
test_acc.max()
# Out:
# 0.97562499999999996

# %%
# %%time
niter = 100
test_interval = 20
# losses will also be stored in the log
train_loss = zeros(niter)
test_loss = zeros(niter)
test_acc = zeros(int(np.ceil(niter / test_interval)))
output = zeros((niter, 8, 123))

# the main solver loop
for it in range(niter):
    solver.step(1)  # SGD by Caffe
    
    # store the train loss
    train_loss[it] = solver.net.blobs['loss'].data
    
    # store the output on the first test batch
    # (start the forward pass at conv1 to avoid loading new data)
    solver.test_nets[0].forward(start='conv1')
    
    output[it] = solver.test_nets[0].blobs['fc4ft'].data[:8]
# Out:
# CPU times: user 1min 22s, sys: 28.4 s, total: 1min 50s
# Wall time: 1min 40s

# %%
for i in range(8):
    figure(figsize=(2, 2))
    imshow(solver.test_nets[0].blobs['data'].data[i, 0], cmap='gray')
    plt.title(r"$%s$"%solver.test_nets[0].blobs['label'].data[i])
    figure(figsize=(10, 2))
    imshow(output[:50, i].T, interpolation='nearest', cmap='gray')
    xlabel('iteration')
    ylabel('label')

# %%
for i in range(8):
    figure(figsize=(2, 2))
    imshow(solver.test_nets[0].blobs['data'].data[i, 0], cmap='gray')
    plt.title(r"$%s$"%solver.test_nets[0].blobs['label'].data[i])
    figure(figsize=(10, 2))
    imshow(exp(output[:50, i].T) / exp(output[:50, i].T).sum(0), interpolation='nearest', cmap='gray')
    xlabel('iteration')
    ylabel('label')

# %%
testacc0_4 = [0.97562499999999996,]
